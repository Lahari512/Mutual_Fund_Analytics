# %% [markdown]
# ## Insight 1
#
# There are 40 mutual fund schemes across 10 fund houses in the dataset.
#
# Reference:
# Fund Master Analysis

# %% [markdown]
# ## Insight 2
#
# All AMFI scheme codes from fund_master.csv exist in nav_history.csv, indicating referential integrity.
#
# Reference:
# AMFI Validation

# %% [markdown]
# ## Insight 3
#
# Monthly SIP inflows steadily increased between January 2022 and December 2025, reaching ₹31,002 crore.
#
# Reference:
# SIP Time Series

# %% [markdown]
# ## Insight 4
#
# Large Cap, Mid Cap, and Flexi Cap categories consistently attracted the highest inflows.
#
# Reference:
# Category Heatmap

# %% [markdown]
# ## Insight 5
#
# Investors aged 26–35 and 36–45 contribute the largest share of SIP investments.
#
# Reference:
# Investor Demographics

# %% [markdown]
# ## Insight 6
#
# The gender distribution of investors is relatively balanced, indicating broad participation.
#
# Reference:
# Gender Distribution

# %% [markdown]
# ## Insight 7
#
# T30 cities contribute a larger proportion of SIP transactions compared with B30 cities.
#
# Reference:
# Geographic Distribution

# %% [markdown]
# ## Insight 8
#
# Industry folio count grew from 13.26 crore in January 2022 to 26.12 crore by December 2025.
#
# Reference:
# Folio Growth

# %% [markdown]
# ## Insight 9
#
# Most selected large-cap funds exhibit strong positive correlations in daily NAV returns, reflecting similar market exposure.
#
# Reference:
# NAV Correlation Matrix

# %% [markdown]
# ## Insight 10
#
# Banking, IT, Financial Services, and Pharma constitute the largest portfolio allocations across equity schemes.
#
# Reference:
# Sector Allocation
